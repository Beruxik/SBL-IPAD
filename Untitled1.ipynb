# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

df = pd.read_csv("data.csv", header=0)
print(df.shape)
df.head()
# Out:
# (43800, 3)
#                   date  pollution  temp
# 0  2010-01-02 00:00:00      129.0  -4.0
# 1  2010-01-02 01:00:00      148.0  -4.0
# 2  2010-01-02 02:00:00      159.0  -5.0
# 3  2010-01-02 03:00:00      181.0  -5.0
# 4  2010-01-02 04:00:00      138.0  -5.0

# %%
# wykres całego dataframe
time = df["date"]
pollution = df["pollution"]
temp = df["temp"]

# Tworzenie wykresu kolumn
plt.bar(time, pollution)

# Dodawanie etykiet na osiach
plt.xlabel("Time")
plt.ylabel("Pollution")

# Wyświetlanie wykresu
plt.show()

# %%
# Wyodrębnij zakresy dat
range_2010_2011 = df.loc[
    (df["date"] >= "2010-01-01") & (df["date"] < "2011-01-01")
].reset_index(drop=True)
range_2011_2012 = df.loc[
    (df["date"] >= "2011-01-01") & (df["date"] < "2012-01-01")
].reset_index(drop=True)
range_2012_end = df.loc[df["date"] >= "2012-01-01"].reset_index(drop=True)


# Dodaj kolumnę z indeksami jako nową kolumnę DataFrame
range_2010_2011["index"] = range_2010_2011.index
range_2011_2012["index"] = range_2011_2012.index
range_2012_end["index"] = range_2012_end.index


# Wyświetl wyniki
print("Zakres 2010-2011:")
print(range_2010_2011)

print("Zakres 2011-2012:")
print(range_2011_2012)

print("Zakres 2012 do końca:")
print(range_2012_end)
# Out:
# Zakres 2010-2011:
#                      date  pollution  temp  index
# 0     2010-01-02 00:00:00      129.0  -4.0      0
# 1     2010-01-02 01:00:00      148.0  -4.0      1
# 2     2010-01-02 02:00:00      159.0  -5.0      2
# 3     2010-01-02 03:00:00      181.0  -5.0      3
# 4     2010-01-02 04:00:00      138.0  -5.0      4
# ...                   ...        ...   ...    ...
# 8731  2010-12-31 19:00:00       27.0  -5.0   8731
# 8732  2010-12-31 20:00:00       17.0  -6.0   8732
# 8733  2010-12-31 21:00:00       19.0  -6.0   8733
# 8734  2010-12-31 22:00:00       16.0  -7.0   8734
# 8735  2010-12-31 23:00:00       22.0  -7.0   8735
#
# [8736 rows x 4 columns]
# Zakres 2011-2012:
#                      date  pollution  temp  index
# 0     2011-01-01 00:00:00        0.0  -9.0      0
# 1     2011-01-01 01:00:00        0.0 -10.0      1
# 2     2011-01-01 02:00:00        0.0 -11.0      2
# 3     2011-01-01 03:00:00        0.0 -10.0      3
# 4     2011-01-01 04:00:00        0.0 -12.0      4
# ...                   ...        ...   ...    ...
# 8755  2011-12-31 19:00:00      209.0  -3.0   8755
# 8756  2011-12-31 20:00:00      217.0  -6.0   8756
# 8757  2011-12-31 21:00:00      223.0  -6.0   8757
# 8758  2011-12-31 22:00:00      251.0  -6.0   8758
# 8759  2011-12-31 23:00:00      283.0  -6.0   8759
#
# [8760 rows x 4 columns]
# Zakres 2012 do końca:
#                       date  pollution  temp  index
# 0      2012-01-01 00:00:00      275.0  -8.0      0
# 1      2012-01-01 01:00:00      303.0 -10.0      1
# 2      2012-01-01 02:00:00      215.0  -9.0      2
# 3      2012-01-01 03:00:00      222.0  -9.0      3
# 4      2012-01-01 04:00:00       85.0  -4.0      4
# ...                    ...        ...   ...    ...
# 26299  2014-12-31 19:00:00        8.0  -2.0  26299
# 26300  2014-12-31 20:00:00       10.0  -3.0  26300
# 26301  2014-12-31 21:00:00       10.0  -3.0  26301
# 26302  2014-12-31 22:00:00        8.0  -4.0  26302
# 26303  2014-12-31 23:00:00       12.0  -3.0  26303
#
# [26304 rows x 4 columns]

# %%
plt.figure(figsize=(10, 6))

# Wykres dla zakresu 2010-2011
plt.subplot(2, 2, 1)
plt.plot(range_2010_2011["date"], range_2010_2011["temp"], label="Temp")
plt.plot(range_2010_2011["date"], range_2010_2011["pollution"], label="Pollution")
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("2010-2011")
plt.legend()

# %%
# Wykres dla zakresu 2011-2012
plt.subplot(2, 2, 2)
plt.plot(range_2011_2012["date"], range_2011_2012["temp"], label="Temp")
plt.plot(range_2011_2012["date"], range_2011_2012["pollution"], label="Pollution")
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("2011-2012")
plt.legend()

# %%
# Wykres dla zakresu 2012 do końca
plt.subplot(2, 2, 3)
plt.plot(range_2012_end["date"], range_2012_end["temp"], label="Temp")
plt.plot(range_2012_end["date"], range_2012_end["pollution"], label="Pollution")
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("2012 to end")
plt.legend()

# %%
# Dostosowanie wyglądu wykresów
plt.tight_layout()

# Wyświetlenie wykresów
plt.show()

# %%
def make_predictions(data, num_days):
    # Przygotowanie danych
    time_series = data[
        "pollution"
    ].values  # Wybierz zmienną celu (np. pollution) jako tablicę wartości

    # Dopasowanie modelu ARIMA
    model = ARIMA(
        time_series, order=(1, 0, 0)
    )  # Przykładowe parametry modelu ARIMA - do dostosowania
    model_fit = model.fit()

    # Prognozowanie
    forecast = model_fit.forecast(steps=num_days)

    return forecast

# %%
# Prognozowanie dla zakresu 2010-2011
forecast_2010_2011 = make_predictions(range_2010_2011, 5)
print("Prognozy dla zakresu 2010-2011:")
print(forecast_2010_2011)
# Out:
# Prognozy dla zakresu 2010-2011:
# [26.23269651 30.22447299 33.98904231 37.53933684 40.88755284]

# %%
# Prognozowanie dla zakresu 2011-2012
forecast_2011_2012 = make_predictions(range_2011_2012, 5)
print("Prognozy dla zakresu 2011-2012:")
print(forecast_2011_2012)
# Out:
# Prognozy dla zakresu 2011-2012:
# [275.14580128 267.61262566 260.38735203 253.45739558 246.81068586]

# %%
# Prognozowanie dla zakresu 2012+
forecast_2012_end = make_predictions(range_2012_end, 5)
print("Prognozy dla zakresu 2012+:")
print(forecast_2012_end)
# Out:
# Prognozy dla zakresu 2012+:
# [15.43040184 18.71780234 21.8681627  24.88719566 27.78037578]

# %%
# funkcja prognozująca zanieczyszczenie
def make_predictions_pollution(data, num_days):
    # Przygotowanie danych
    time_series = data[
        "pollution"
    ].values  # Wybierz zmienną celu (np. pollution) jako tablicę wartości

    # Dopasowanie modelu ARIMA
    model = ARIMA(
        time_series, order=(1, 0, 0)
    )  # Przykładowe parametry modelu ARIMA - do dostosowania
    model_fit = model.fit()

    # Prognozowanie
    forecast_values = model_fit.forecast(steps=num_days)

    # Tworzenie DataFrame z prognozami
    dates = pd.date_range(start=data["date"].iloc[-1], periods=num_days + 1, freq="D")[
        1:
    ]  # Wygeneruj daty dla prognoz
    forecast_df = pd.DataFrame({"Date": dates, "Forecast": forecast_values})

    return forecast_df

# %%
# Wyswietlanie predykcji zanieczyszczenia dla zakresu od 1 stycznia do 5 stycznie 2011
forecast_2010_2011 = make_predictions_pollution(range_2010_2011, 5)
print("Prognozy dla zakresu 2010-2011:")
print(forecast_2010_2011)
# Out:
# Prognozy dla zakresu 2010-2011:
#                  Date   Forecast
# 0 2011-01-01 23:00:00  26.232697
# 1 2011-01-02 23:00:00  30.224473
# 2 2011-01-03 23:00:00  33.989042
# 3 2011-01-04 23:00:00  37.539337
# 4 2011-01-05 23:00:00  40.887553

# %%
# Wyswietlanie predykcji zanieczyszczenia dla zakresu od 1 stycznia do 5 stycznie 2012
forecast_2011_2012 = make_predictions_pollution(range_2011_2012, 5)
print("Prognozy dla zakresu 2011-2012:")
print(forecast_2011_2012)
# Out:
# Prognozy dla zakresu 2011-2012:
#                  Date    Forecast
# 0 2012-01-01 23:00:00  275.145801
# 1 2012-01-02 23:00:00  267.612626
# 2 2012-01-03 23:00:00  260.387352
# 3 2012-01-04 23:00:00  253.457396
# 4 2012-01-05 23:00:00  246.810686

# %%
# Wyswietlanie predykcji zanieczyszczenia dla zakresu od 1 stycznia do 5 stycznie 2013
forecast_2012_end = make_predictions_pollution(range_2012_end, 5)
print("Prognozy dla zakresu 2012+:")
print(forecast_2012_end)
# Out:
# Prognozy dla zakresu 2012+:
#                  Date   Forecast
# 0 2015-01-01 23:00:00  15.430402
# 1 2015-01-02 23:00:00  18.717802
# 2 2015-01-03 23:00:00  21.868163
# 3 2015-01-04 23:00:00  24.887196
# 4 2015-01-05 23:00:00  27.780376

# %%
def make_predictions_temp(data, num_days):
    # Przygotowanie danych
    time_series = data[
        "temp"
    ].values  # Wybierz zmienną celu (np. pollution) jako tablicę wartości

    # Dopasowanie modelu ARIMA
    model = ARIMA(
        time_series, order=(1, 0, 0)
    )  # Przykładowe parametry modelu ARIMA - do dostosowania
    model_fit = model.fit()

    # Prognozowanie
    forecast_values = model_fit.forecast(steps=num_days)

    # Tworzenie DataFrame z prognozami
    dates = pd.date_range(start=data["date"].iloc[-1], periods=num_days + 1, freq="D")[
        1:
    ]  # Wygeneruj daty dla prognoz
    forecast_df = pd.DataFrame({"Date": dates, "Forecast": forecast_values})

    return forecast_df

# %%
# prognoza temperatury dla 1 do 30 stycznia 2011
forecast_2010_2011_temp = make_predictions_temp(range_2010_2011, 30)
print("Prognozy temperatury dla zakresu 2010-2011:")
print(forecast_2010_2011_temp)
# Out:
# Prognozy temperatury dla zakresu 2010-2011:
#                   Date  Forecast
# 0  2011-01-01 23:00:00 -6.883419
# 1  2011-01-02 23:00:00 -6.767565
# 2  2011-01-03 23:00:00 -6.652434
# 3  2011-01-04 23:00:00 -6.538021
# 4  2011-01-05 23:00:00 -6.424322
# 5  2011-01-06 23:00:00 -6.311333
# 6  2011-01-07 23:00:00 -6.199049
# 7  2011-01-08 23:00:00 -6.087465
# 8  2011-01-09 23:00:00 -5.976578
# 9  2011-01-10 23:00:00 -5.866383
# 10 2011-01-11 23:00:00 -5.756875
# 11 2011-01-12 23:00:00 -5.648051
# 12 2011-01-13 23:00:00 -5.539906
# 13 2011-01-14 23:00:00 -5.432435
# 14 2011-01-15 23:00:00 -5.325635
# 15 2011-01-16 23:00:00 -5.219502
# 16 2011-01-17 23:00:00 -5.114031
# 17 2011-01-18 23:00:00 -5.009218
# 18 2011-01-19 23:00:00 -4.905059
# 19 2011-01-20 23:00:00 -4.801550
# 20 2011-01-21 23:00:00 -4.698687
# 21 2011-01-22 23:00:00 -4.596465
# 22 2011-01-23 23:00:00 -4.494882
# 23 2011-01-24 23:00:00 -4.393933
# 24 2011-01-25 23:00:00 -4.293613
# 25 2011-01-26 23:00:00 -4.193919
# 26 2011-01-27 23:00:00 -4.094848
# 27 2011-01-28 23:00:00 -3.996395
# 28 2011-01-29 23:00:00 -3.898556
# 29 2011-01-30 23:00:00 -3.801327

# %%
# prognoza temperatury dla 1 do 30 stycznia 2012
forecast_2011_2012_temp = make_predictions_temp(range_2011_2012, 30)
print("Prognozy temperatury dla zakresu 2011-2012:")
print(forecast_2011_2012_temp)
# Out:
# Prognozy temperatury dla zakresu 2011-2012:
#                   Date  Forecast
# 0  2012-01-01 23:00:00 -5.855113
# 1  2012-01-02 23:00:00 -5.711356
# 2  2012-01-03 23:00:00 -5.568721
# 3  2012-01-04 23:00:00 -5.427199
# 4  2012-01-05 23:00:00 -5.286782
# 5  2012-01-06 23:00:00 -5.147461
# 6  2012-01-07 23:00:00 -5.009227
# 7  2012-01-08 23:00:00 -4.872071
# 8  2012-01-09 23:00:00 -4.735987
# 9  2012-01-10 23:00:00 -4.600964
# 10 2012-01-11 23:00:00 -4.466995
# 11 2012-01-12 23:00:00 -4.334071
# 12 2012-01-13 23:00:00 -4.202185
# 13 2012-01-14 23:00:00 -4.071328
# 14 2012-01-15 23:00:00 -3.941492
# 15 2012-01-16 23:00:00 -3.812670
# 16 2012-01-17 23:00:00 -3.684853
# 17 2012-01-18 23:00:00 -3.558033
# 18 2012-01-19 23:00:00 -3.432204
# 19 2012-01-20 23:00:00 -3.307356
# 20 2012-01-21 23:00:00 -3.183482
# 21 2012-01-22 23:00:00 -3.060576
# 22 2012-01-23 23:00:00 -2.938628
# 23 2012-01-24 23:00:00 -2.817632
# 24 2012-01-25 23:00:00 -2.697581
# 25 2012-01-26 23:00:00 -2.578466
# 26 2012-01-27 23:00:00 -2.460281
# 27 2012-01-28 23:00:00 -2.343018
# 28 2012-01-29 23:00:00 -2.226671
# 29 2012-01-30 23:00:00 -2.111231

# %%
# prognoza temperatury dla 1 do 30 stycznia 2013
forecast_2012_temp = make_predictions_temp(range_2012_end, 30)
print("Prognozy temperatury dla zakresu 2012+:")
print(forecast_2012_temp)
# Out:
# Prognozy temperatury dla zakresu 2012+:
#                   Date  Forecast
# 0  2015-01-01 23:00:00 -2.875700
# 1  2015-01-02 23:00:00 -2.752385
# 2  2015-01-03 23:00:00 -2.630048
# 3  2015-01-04 23:00:00 -2.508681
# 4  2015-01-05 23:00:00 -2.388275
# 5  2015-01-06 23:00:00 -2.268824
# 6  2015-01-07 23:00:00 -2.150320
# 7  2015-01-08 23:00:00 -2.032755
# 8  2015-01-09 23:00:00 -1.916122
# 9  2015-01-10 23:00:00 -1.800414
# 10 2015-01-11 23:00:00 -1.685622
# 11 2015-01-12 23:00:00 -1.571741
# 12 2015-01-13 23:00:00 -1.458762
# 13 2015-01-14 23:00:00 -1.346679
# 14 2015-01-15 23:00:00 -1.235484
# 15 2015-01-16 23:00:00 -1.125171
# 16 2015-01-17 23:00:00 -1.015732
# 17 2015-01-18 23:00:00 -0.907160
# 18 2015-01-19 23:00:00 -0.799449
# 19 2015-01-20 23:00:00 -0.692592
# 20 2015-01-21 23:00:00 -0.586582
# 21 2015-01-22 23:00:00 -0.481412
# 22 2015-01-23 23:00:00 -0.377076
# 23 2015-01-24 23:00:00 -0.273567
# 24 2015-01-25 23:00:00 -0.170878
# 25 2015-01-26 23:00:00 -0.069004
# 26 2015-01-27 23:00:00  0.032063
# 27 2015-01-28 23:00:00  0.132329
# 28 2015-01-29 23:00:00  0.231801
# 29 2015-01-30 23:00:00  0.330484

# %%
print(range_2010_2011.head())
print(range_2011_2012.head())
print(range_2012_end.head())
# Out:
#                   date  pollution  temp  index
# 0  2010-01-02 00:00:00      129.0  -4.0      0
# 1  2010-01-02 01:00:00      148.0  -4.0      1
# 2  2010-01-02 02:00:00      159.0  -5.0      2
# 3  2010-01-02 03:00:00      181.0  -5.0      3
# 4  2010-01-02 04:00:00      138.0  -5.0      4
#                   date  pollution  temp  index
# 0  2011-01-01 00:00:00        0.0  -9.0      0
# 1  2011-01-01 01:00:00        0.0 -10.0      1
# 2  2011-01-01 02:00:00        0.0 -11.0      2
# 3  2011-01-01 03:00:00        0.0 -10.0      3
# 4  2011-01-01 04:00:00        0.0 -12.0      4
#                   date  pollution  temp  index
# 0  2012-01-01 00:00:00      275.0  -8.0      0
# 1  2012-01-01 01:00:00      303.0 -10.0      1
# 2  2012-01-01 02:00:00      215.0  -9.0      2
# 3  2012-01-01 03:00:00      222.0  -9.0      3
# 4  2012-01-01 04:00:00       85.0  -4.0      4

# %%
# LSTM czyli (Long Short-Term Memory) jest rodzajem rekurencyjnej sieci neuronowej (RNN), która jest efektywna w analizie i przewidywaniu danych sekwencyjnych, takich jak dane czasowe.

# %%
# Wczytanie danych
df = pd.read_csv("data.csv", header=0)
df["date"] = pd.to_datetime(df["date"])
df = df.set_index("date")

# %%
# Wyodrębnienie zakresu dat
start_date_2010_2011 = pd.to_datetime("2010-01-01")
end_date_2010_2011 = pd.to_datetime("2011-01-01")
data_2010_2011 = df.loc[(df.index >= start_date_2010_2011) & (df.index < end_date_2010_2011)]

# %%
# Przygotowanie danych
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data_2010_2011["temp"].values.reshape(-1, 1))

# %%
# Podział danych na zestawy treningowe i testowe
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

# %%
# Tworzenie sekwencji danych
def create_sequences(data, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i : i + sequence_length])
        y.append(data[i + sequence_length])
    return np.array(X), np.array(y)


sequence_length = 10
X_train, y_train = create_sequences(train_data, sequence_length)
X_test, y_test = create_sequences(test_data, sequence_length)

# %%
# Budowa modelu LSTM
model = Sequential()
model.add(LSTM(64, activation="relu", input_shape=(sequence_length, 1)))
model.add(Dense(1))
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
# Trenowanie modelu
model.fit(X_train, y_train, epochs=10, batch_size=16)
# Out:
# Epoch 1/10
# 437/437 [==============================] - 4s 4ms/step - loss: 0.0153
# Epoch 2/10
# 437/437 [==============================] - 2s 4ms/step - loss: 0.0014
# Epoch 3/10
# 437/437 [==============================] - 2s 4ms/step - loss: 0.0011
# Epoch 4/10
# 437/437 [==============================] - 2s 4ms/step - loss: 8.1770e-04
# Epoch 5/10
# 437/437 [==============================] - 2s 4ms/step - loss: 6.4954e-04
# Epoch 6/10
# 437/437 [==============================] - 2s 4ms/step - loss: 5.4861e-04
# Epoch 7/10
# 437/437 [==============================] - 2s 4ms/step - loss: 5.2487e-04
# Epoch 8/10
# 437/437 [==============================] - 2s 4ms/step - loss: 5.0863e-04
# Epoch 9/10
# 437/437 [==============================] - 2s 4ms/step - loss: 4.7917e-04
# Epoch 10/10
# 437/437 [==============================] - 2s 4ms/step - loss: 4.8435e-04

# %%
# Prognozowanie
predicted_data = model.predict(X_test)
# Out:
# 55/55 [==============================] - 0s 2ms/step

# %%
# Odwrócenie skalowania danych
predicted_data = scaler.inverse_transform(predicted_data)

# %%
# Wykres prognoz i rzeczywistych wartości
plt.plot(data_2010_2011.index[train_size + sequence_length :], predicted_data, label="Prognoza")
plt.plot(
    data_2010_2011.index[train_size + sequence_length :],
    data_2010_2011["temp"].values[train_size + sequence_length :],
    label="Rzeczywiste wartości",
)
plt.xlabel("Data")
plt.ylabel("Temperatura")
plt.legend()
plt.show()

# %%
# Wczytanie danych
df = pd.read_csv("data.csv", header=0)
df["date"] = pd.to_datetime(df["date"])
df = df.set_index("date")

# %%
# Wyodrębnienie zakresu dat
start_date_2011_2012 = pd.to_datetime("2011-01-01")
end_date_2011_2012 = pd.to_datetime("2012-01-01")
data_2011_2012 = df.loc[(df.index >= start_date_2011_2012) & (df.index < end_date_2011_2012)]

# %%
# Przygotowanie danych
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data_2011_2012["temp"].values.reshape(-1, 1))

# %%
# Podział danych na zestawy treningowe i testowe
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

# %%
# Tworzenie sekwencji danych
sequence_length = 10
X_train, y_train = create_sequences(train_data, sequence_length)
X_test, y_test = create_sequences(test_data, sequence_length)

# %%
# Budowa modelu LSTM
model = Sequential()
model.add(LSTM(64, activation="relu", input_shape=(sequence_length, 1)))
model.add(Dense(1))
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
# Trenowanie modelu
model.fit(X_train, y_train, epochs=10, batch_size=16)
# Out:
# Epoch 1/10
# 438/438 [==============================] - 3s 4ms/step - loss: 0.0220
# Epoch 2/10
# 438/438 [==============================] - 2s 5ms/step - loss: 0.0026
# Epoch 3/10
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0018
# Epoch 4/10
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0012
# Epoch 5/10
# 438/438 [==============================] - 2s 4ms/step - loss: 8.7084e-04
# Epoch 6/10
# 438/438 [==============================] - 2s 4ms/step - loss: 8.4578e-04
# Epoch 7/10
# 438/438 [==============================] - 2s 4ms/step - loss: 8.0696e-04
# Epoch 8/10
# 438/438 [==============================] - 2s 4ms/step - loss: 7.9456e-04
# Epoch 9/10
# 438/438 [==============================] - 2s 4ms/step - loss: 7.5581e-04
# Epoch 10/10
# 438/438 [==============================] - 2s 4ms/step - loss: 7.9164e-04

# %%
# Prognozowanie
predicted_data = model.predict(X_test)
# Out:
# 55/55 [==============================] - 0s 2ms/step

# %%
# Odwrócenie skalowania danych
predicted_data = scaler.inverse_transform(predicted_data)

# %%
# Wykres prognoz i rzeczywistych wartości
plt.plot(data_2011_2012.index[train_size + sequence_length :], predicted_data, label="Prognoza")
plt.plot(
    data_2011_2012.index[train_size + sequence_length :],
    data_2011_2012["temp"].values[train_size + sequence_length :],
    label="Rzeczywiste wartości",
)
plt.xlabel("Data")
plt.ylabel("Temperatura")
plt.legend()
plt.show()

# %%
# Wczytanie danych
df = pd.read_csv("data.csv", header=0)
df["date"] = pd.to_datetime(df["date"])
df = df.set_index("date")

# %%
# Wyodrębnienie zakresu dat
start_date_2012_end = pd.to_datetime("2012-01-01")
data_2012_end = df.loc[(df.index >= start_date_2012_end)]

# %%
# Przygotowanie danych
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data_2012_end["temp"].values.reshape(-1, 1))

# %%
# Podział danych na zestawy treningowe i testowe
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

# %%
# Tworzenie sekwencji danych
sequence_length = 10
X_train, y_train = create_sequences(train_data, sequence_length)
X_test, y_test = create_sequences(test_data, sequence_length)

# %%
# Budowa modelu LSTM
model = Sequential()
model.add(LSTM(64, activation="relu", input_shape=(sequence_length, 1)))
model.add(Dense(1))
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
# Trenowanie modelu
model.fit(X_train, y_train, epochs=10, batch_size=16)
# Out:
# Epoch 1/10
# 1315/1315 [==============================] - 6s 4ms/step - loss: 0.0040
# Epoch 2/10
# 1315/1315 [==============================] - 5s 4ms/step - loss: 7.1243e-04
# Epoch 3/10
# 1315/1315 [==============================] - 5s 4ms/step - loss: 6.0906e-04
# Epoch 4/10
# 1315/1315 [==============================] - 5s 4ms/step - loss: 6.0009e-04
# Epoch 5/10
# 1315/1315 [==============================] - 5s 4ms/step - loss: 5.8281e-04
# Epoch 6/10
# 1315/1315 [==============================] - 5s 4ms/step - loss: 5.6447e-04
# Epoch 7/10
# 1315/1315 [==============================] - 5s 4ms/step - loss: 5.5564e-04
# Epoch 8/10
# 1315/1315 [==============================] - 5s 4ms/step - loss: 5.3695e-04
# Epoch 9/10
# 1315/1315 [==============================] - 5s 4ms/step - loss: 5.2875e-04
# Epoch 10/10
# 1315/1315 [==============================] - 5s 4ms/step - loss: 5.2650e-04

# %%
# Prognozowanie
predicted_data = model.predict(X_test)
# Out:
# 165/165 [==============================] - 0s 2ms/step

# %%
# Odwrócenie skalowania danych
predicted_data = scaler.inverse_transform(predicted_data)

# %%
# Wykres prognoz i rzeczywistych wartości
plt.plot(data_2012_end.index[train_size + sequence_length :], predicted_data, label="Prognoza")
plt.plot(
    data_2012_end.index[train_size + sequence_length :],
    data_2012_end["temp"].values[train_size + sequence_length :],
    label="Rzeczywiste wartości",
)
plt.xlabel("Data")
plt.ylabel("Temperatura")
plt.legend()
plt.show()

# %%
# regresja liniowa

# %%
# Wczytaj dane
df = pd.read_csv("data.csv")
df["date"] = pd.to_datetime(df["date"])

# %%
# Podziel dane na cechy (X) i etykiety (y)
X = df["date"].values.reshape(-1, 1)
y_pollution = df["pollution"].values
y_temp = df["temp"].values

# %%
# Podziel dane na zestawy treningowe i testowe
X_train, X_test, y_train, y_test = train_test_split(
    X, y_pollution, test_size=0.2, random_state=42
)

# %%
# Utwórz i wytrenuj model regresji liniowej
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Przed wywołaniem predict
X_test = X_test.astype(float)
y_pred = model.predict(X_test)

# %%
# Oblicz średni błąd kwadratowy
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 8813.605892661717

# %%
# Wykonaj prognozę na kolejnych dniach
num_days = 5
last_date = df["date"].max()

future_dates_numeric = (
    np.array(future_dates, dtype="datetime64[D]") - np.datetime64("1970-01-01")
).astype(np.int64) // 10**9
future_dates_numeric = np.array(future_dates_numeric).reshape(-1, 1)

future_predictions = model.predict(future_dates_numeric)

print("Prognozy dla kolejnych", num_days, "dni:")
for date, prediction in zip(future_dates, future_predictions):
    print(date, ":", prediction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 6
#       2 num_days = 5
#       3 last_date = df["date"].max()
#       5 future_dates_numeric = (
# ----> 6     np.array(future_dates, dtype="datetime64[D]") - np.datetime64("1970-01-01")
#       7 ).astype(np.int64) // 10**9
#       8 future_dates_numeric = np.array(future_dates_numeric).reshape(-1, 1)
#      10 future_predictions = model.predict(future_dates_numeric)
#
# NameError: name 'future_dates' is not defined

# %%
future_dates_numeric = (
    np.array(future_dates, dtype="datetime64[D]") - np.datetime64("1970-01-01")
).astype(np.int64) // 10**9
future_dates_numeric = np.array(future_dates_numeric).reshape(-1, 1)

# %%
print(future_dates_numeric)
# Out:
# [[0]
#  [0]
#  [0]
#  [0]
#  [0]]
